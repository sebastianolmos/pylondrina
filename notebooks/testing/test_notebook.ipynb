# %%
from pathlib import Path
import sys

REPO_ROOT = Path("../..").resolve()
if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))

DATA_PATH = REPO_ROOT / "data" / "synthetic" / "dummy_dataset.csv"

import pandas as pd

# %%
from scripts.test_function import test_print

test_print("Poyo!")

df_csv = pd.read_csv(DATA_PATH)
display(df_csv)
# Out:
# Estoy en scripts :D  Poyo!
#    id     name category  value  created_at
# 0   1    alpha        A     10  2026-03-21
# 1   2     beta        B     20  2026-03-22
# 2   3    gamma        A     30  2026-03-23
# 3   4    delta        C     40  2026-03-24
# 4   5  epsilon        B     50  2026-03-25
